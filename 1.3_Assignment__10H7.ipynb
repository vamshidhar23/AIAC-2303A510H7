# %% [markdown]
# <a href="https://colab.research.google.com/github/vamshidhar23/AIAC-2303A510H7/blob/main/1.3_Assignment__10H7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Q1. Write a Python program to print Fibonacci series up to n terms
# Take user input
# Do not use functions
n = int(input("Enter number of terms: "))

a = 0
b = 1

if n <= 0:
    print("Please enter a positive number")
elif n == 1:
    print(a)
else:
    print("Fibonacci sequence:")
    print(a, b, end=" ")
    for i in range(2, n):
        c = a + b
        print(c, end=" ")
        a = b
        b = c
# Out:
# Enter number of terms: 7
# Fibonacci sequence:
# 0 1 1 2 3 5 8

# %%
# Q2.Optimize this Fibonacci code
# Simplify logic and variable usage
n = int(input("Enter number of terms: "))

a, b = 0, 1

if n <= 0:
    print("Please enter a positive number")
else:
    print("Fibonacci sequence:")
    for _ in range(n):
        print(a, end=" ")
        a, b = b, a + b
# Out:
# Enter number of terms: 5
# Fibonacci sequence:
# 0 1 1 2 3

# %%
# Q3.Create a function to generate Fibonacci series up to n
# Use meaningful comments
def fibonacci(n):
    """
    Generates Fibonacci sequence up to n terms
    """
    a, b = 0, 1
    sequence = []

    for _ in range(n):
        sequence.append(a)
        a, b = b, a + b

    return sequence


n = int(input("Enter number of terms: "))
result = fibonacci(n)
print("Fibonacci sequence:", result)
# Out:
# Enter number of terms: 6
# Fibonacci sequence: [0, 1, 1, 2, 3, 5]

# %% [markdown]
# Task 4: Comparative Analysis
#
# Modular programming improves readability, reusability, and debugging efficiency, making it more suitable for real-world systems.

# %%
#Q5.AI-Generated Iterative vs Recursive Fibonacci Approaches (Different Algorithmic Approaches for Fibonacci Series)
def fibonacci_iterative(n):
    a, b = 0, 1
    for _ in range(n):
        print(a, end=" ")
        a, b = b, a + b


n = int(input("Enter number of terms: "))
fibonacci_iterative(n)
def fibonacci_recursive(n):
    if n <= 1:
        return n
    return fibonacci_recursive(n - 1) + fibonacci_recursive(n - 2)


n = int(input("Enter number of terms: "))
for i in range(n):
    print(fibonacci_recursive(i), end=" ")
# Out:
# Enter number of terms: 6
# 0 1 1 2 3 5 Enter number of terms: 3
# 0 1 1
